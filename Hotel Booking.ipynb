# %% [markdown]
# ## Hotel Booking Analysis

# %%
#inporting basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()
import warnings
warnings.filterwarnings("ignore")

# %%
#reading the hotel booking data
data=pd.read_csv("hotel_bookings.csv")
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
#Analysing the size
data.shape
# Out:
# (119390, 32)

# %%
#getting datatype of all columns
data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
#checking the null values if any
data.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#filling null/missing values
data.fillna({'country':'unknown','children':0,'agent':0},inplace=True)

# %%
#droping company as their is very lss data
data.drop('company',axis=1,inplace=True)

# %%
#free of null valu3
data.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %%
#checking and deleting duplicates
data.duplicated()
data=data.drop_duplicates()

# %%
#checking correlation
plt.figure(figsize=(18,10))
sb.heatmap(data.corr(),annot=True,cmap="Reds",linecolor="white")

# %% [markdown]
# ### Checking Features Visually

# %%
data.hotel.value_counts()
# Out:
# City Hotel      53426
# Resort Hotel    33963
# Name: hotel, dtype: int64

# %%
data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
#checking the types of hotel preffered mostly
data.hotel.value_counts().plot.bar(color="pink")

# %%
data.lead_time
# Out:
# 0         342
# 1         737
# 2           7
# 3          13
# 4          14
#          ...
# 119385     23
# 119386    102
# 119387     34
# 119388    109
# 119389    205
# Name: lead_time, Length: 87389, dtype: int64

# %%
#histogram to show how much time guest do the booking
plt.figure(figsize=(15,5))
data.lead_time.plot.hist(bins=41,edgecolor="blue")
plt.title("how much time guest do booking")
plt.xlabel("no of time")
# Out:
# Text(0.5, 0, 'no of time')

# %%
#cancellation rate
data.is_canceled.value_counts().plot.bar()
plt.xticks([0,1],['booked','cancel'])
# Out:
# ([<matplotlib.axis.XTick at 0x1cbcf220e48>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
# Also, let's see how many cancellations are there in each hotel
sb.countplot(data.hotel,hue=data.is_canceled)

# %%
data.groupby('hotel')['is_canceled'].value_counts(normalize=True)*100
# Out:
# hotel         is_canceled
# City Hotel    0              69.960319
#               1              30.039681
# Resort Hotel  0              76.515620
#               1              23.484380
# Name: is_canceled, dtype: float64

# %%
#price of hotel room
#removing outlier
data.adr.quantile([.70,.80,.90,.95,.99])
data=data[data.adr<261]

# %%
#plotting adr
sb.boxplot(data.adr)
data.shape
# Out:
# (86497, 31)

# %%
#prices round the year
sb.barplot(x=data.adr, y=data.arrival_date_month,hue=data.hotel)

# %% [markdown]
# Stay in Week nights v/s Stay in Weekend nights

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86497 entries, 0 to 119389
# Data columns (total 31 columns):
# hotel                             86497 non-null object
# is_canceled                       86497 non-null int64
# lead_time                         86497 non-null int64
# arrival_date_year                 86497 non-null int64
# arrival_date_month                86497 non-null object
# arrival_date_week_number          86497 non-null int64
# arrival_date_day_of_month         86497 non-null int64
# stays_in_weekend_nights           86497 non-null int64
# stays_in_week_nights              86497 non-null int64
# adults                            86497 non-null int64
# children                          86497 non-null float64
# babies                            86497 non-null int64
# meal                              86497 non-null object
# country                           86497 non-null object
# market_segment                    86497 non-null object
# ...

# %%
data.stays_in_week_nights.value_counts()
# Out:
# 1     22038
# 2     20551
# 3     16098
# 5      9503
# 4      7738
# 0      6128
# 6      1363
# 10      965
# 7       955
# 8       603
# 9       215
# 15       68
# 11       50
# 20       41
# 12       40
# 13       27
# 14       25
# 19       21
# 21       15
# 16       13
# 22        7
# 18        6
# 25        6
# 30        5
# 17        4
# 24        2
# 40        2
# 42        1
# 26        1
# 32        1
# 33        1
# 34        1
# 35        1
# 41        1
# 50        1
# Name: stays_in_week_nights, dtype: int64

# %%
a=data[data.stays_in_week_nights<10]
b=data[data.stays_in_weekend_nights<10]

# %%
a.stays_in_week_nights.plot.hist(color='yellow',bins=8,label="weekdays")
b.stays_in_weekend_nights.plot.hist(bins=8,alpha=.5,label="weekends")
plt.legend(loc=1)
plt.xlabel("no. of days")
plt.ylabel("no of booking")
plt.title("no of booking in week and weekends")
# Out:
# Text(0.5, 1.0, 'no of booking in week and weekends')

# %%
#Average Daily Price with respect to the room type
z1=data.groupby('reserved_room_type')['adr'].agg({'average_price':'mean','no of booking':'size'})

z1
# Out:
#                     average_price  no of booking
# reserved_room_type
# A                       91.934447          56466
# B                       90.009880            997
# C                      150.485998            847
# D                      121.326619          17319
# E                      122.865049           5936
# F                      162.934591           2705
# G                      154.666405           1733
# H                      161.341286            482
# L                      124.666667              6
# P                        0.000000              6

# %%
#visualizing above 
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,6))
ax1.plot(z1.average_price,color='red')

ax2.plot(z1['no of booking'],color='green')

# %%
#Market Segment
plt.figure(figsize=(8,6))
data.market_segment.value_counts(sort=False).plot.pie(autopct='%1.1f%%',startangle=90)

# %%
#Let's see from which countries the guests are bookings
(data.country.value_counts())[:10].plot.bar(color="green")
plt.title("top 10 countries")
# Out:
# Text(0.5, 1.0, 'top 10 countries')

# %%
#Check which type of customers are visiting in each hotel
sb.countplot(data['customer_type'],hue=data.hotel)
